# %%
import yfinance as yf
import pandas as pd
import os
# Out:
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()

# %%
if os.path.exists("sp500.csv"):
    sp500 = pd.read_csv("sp500.csv", index_col=0)
else:
    sp500 = yf.Ticker("^GSPC")
    sp500 = sp500.history(period="max")
    sp500.to_csv("sp500.csv")

# %%
sp500.index = pd.to_datetime(sp500.index)

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-09-06  3930.889893  3942.550049  3886.750000  3908.189941  2209800080
# 2022-09-07  3909.429932  3987.889893  3906.030029  3979.870117           0
# 2022-09-08  3959.939941  4010.500000  3944.810059  4006.179932           0
# 2022-09-09  4022.939941  4076.810059  4022.939941  4067.360107           0
# 2022-09-12  4083.669922  4119.279785  4083.669922  4107.279785  1602969000
#
#             Dividends  Stock Splits
# Date
# ...

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=1000, min_samples_split=50, random_state=1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=50, n_estimators=1000, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["Target"], preds)
# Out:
# 0.5074626865671642

# %%
combined = pd.concat([test["Target"], preds], axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)

    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# 0    3452
# 1    2286
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5376202974628171

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# 1    0.536075
# 0    0.463925
# Name: Target, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()

    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]

    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]

    new_predictors+= [ratio_column, trend_column]

# %%
sp500 = sp500.dropna(subset=sp500.columns[sp500.columns != "Tomorrow"])

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1993-12-14   465.730011   466.119995   462.459991   463.059998   275050000
# 1993-12-15   463.059998   463.690002   461.839996   461.839996   331770000
# 1993-12-16   461.859985   463.980011   461.859985   463.339996   284620000
# 1993-12-17   463.339996   466.380005   463.339996   466.380005   363750000
# 1993-12-20   466.380005   466.899994   465.529999   465.850006   255900000
# ...                 ...          ...          ...          ...         ...
# 2022-09-06  3930.889893  3942.550049  3886.750000  3908.189941  2209800080
# 2022-09-07  3909.429932  3987.889893  3906.030029  3979.870117           0
# 2022-09-08  3959.939941  4010.500000  3944.810059  4006.179932           0
# 2022-09-09  4022.939941  4076.810059  4022.939941  4067.360107           0
# 2022-09-12  4083.669922  4119.279785  4083.669922  4107.279785  1602969000
#
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >=.6] = 1
    preds[preds <.6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# 0.0    3933
# 1.0     805
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5701863354037268

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# 1    0.546855
# 0    0.453145
# Name: Target, dtype: float64

# %%
predictions
# Out:
#             Target  Predictions
# Date
# 2003-11-14       0          0.0
# 2003-11-17       0          1.0
# 2003-11-18       1          1.0
# 2003-11-19       0          0.0
# 2003-11-20       1          1.0
# ...            ...          ...
# 2022-09-06       1          0.0
# 2022-09-07       1          0.0
# 2022-09-08       1          0.0
# 2022-09-09       1          0.0
# 2022-09-12       0          0.0
#
# [4738 rows x 2 columns]

# %%
from sklearn.linear_model import LogisticRegression

logistic_model = LogisticRegression(random_state=1)

logistic_model.fit(train[predictors], train["Target"])
# Out:
# LogisticRegression(random_state=1)

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# Check class distribution
print(train["Target"].value_counts())

# Standardize features
scaler = StandardScaler()
train_scaled = train.copy()
test_scaled = test.copy()

train_scaled[predictors] = scaler.fit_transform(train[predictors])
test_scaled[predictors] = scaler.transform(test[predictors])

# Logistic Regression with adjusted class weights
logistic_model = LogisticRegression(class_weight="balanced", random_state=1)
logistic_model.fit(train_scaled[predictors], train_scaled["Target"])

# Make predictions
logistic_preds = logistic_model.predict(test_scaled[predictors])

# Calculate precision score
precision_logistic = precision_score(test_scaled["Target"], logistic_preds)

# Create a Series for predictions
logistic_preds_series = pd.Series(logistic_preds, index=test.index, name="Logistic_Predictions")

# Plot the results
combined_logistic = pd.concat([test_scaled["Target"], logistic_preds_series], axis=1)
combined_logistic.plot()
plt.title(f"Logistic Regression - Precision: {precision_logistic:.2f}")
plt.show()
# Out:
# 1    4367
# 0    3771
# Name: Target, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_scaled = train.copy()
train_scaled[predictors] = scaler.fit_transform(train[predictors])
test_scaled = test.copy()
test_scaled[predictors] = scaler.transform(test[predictors])

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import precision_score, confusion_matrix
import matplotlib.pyplot as plt

# Naive Bayes
naive_bayes_model = GaussianNB()
naive_bayes_model.fit(train[predictors], train["Target"])

# Precision Score
naive_bayes_preds = naive_bayes_model.predict(test[predictors])
naive_bayes_precision = precision_score(test["Target"], naive_bayes_preds)

# Confusion Matrix
conf_matrix_naive_bayes = confusion_matrix(test["Target"], naive_bayes_preds)

# Visualizing Confusion Matrix
plt.imshow(conf_matrix_naive_bayes, cmap='Blues', interpolation='nearest')
plt.title('Naive Bayes Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Predicted Probabilities for Naive Bayes
naive_bayes_probs = naive_bayes_model.predict_proba(test[predictors])[:, 1]

# Visualizing Predicted Probabilities
plt.figure(figsize=(8, 5))
plt.plot(test.index, naive_bayes_probs, label='Naive Bayes Predicted Probabilities')
plt.title('Naive Bayes Predicted Probabilities')
plt.xlabel('Date')
plt.ylabel('Probability')
plt.legend()
plt.show()

# Additional Diagnostics on Training Data for Naive Bayes
train_preds_nb = naive_bayes_model.predict(train[predictors])
train_probs_nb = naive_bayes_model.predict_proba(train[predictors])[:, 1]

print("Precision on Training Data (Naive Bayes):", precision_score(train["Target"], train_preds_nb))
print("Predicted Probabilities (Naive Bayes):", train_probs_nb)
# Out:
# Precision on Training Data (Naive Bayes): 0.5366183337429343
# Predicted Probabilities (Naive Bayes): [0.52766451 0.52783478 0.52774861 ... 0.54227006 0.54191639 0.54098261]

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import precision_score, confusion_matrix
import matplotlib.pyplot as plt

# Naive Bayes
naive_bayes_model = GaussianNB()
naive_bayes_model.fit(train[predictors], train["Target"])

# Precision Score
naive_bayes_preds = naive_bayes_model.predict(test[predictors])
naive_bayes_precision = precision_score(test["Target"], naive_bayes_preds)
print("Precision Score (Naive Bayes):", naive_bayes_precision)

# Confusion Matrix
conf_matrix_naive_bayes = confusion_matrix(test["Target"], naive_bayes_preds)
print("Confusion Matrix (Naive Bayes):\n", conf_matrix_naive_bayes)

# Visualizing Confusion Matrix
plt.imshow(conf_matrix_naive_bayes, cmap='Blues', interpolation='nearest')
plt.title('Naive Bayes Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Predicted Probabilities for Naive Bayes
naive_bayes_probs = naive_bayes_model.predict_proba(test[predictors])[:, 1]

# Visualizing Predicted Probabilities
plt.figure(figsize=(8, 5))
plt.plot(test.index, naive_bayes_probs, label='Naive Bayes Predicted Probabilities')
plt.title('Naive Bayes Predicted Probabilities')
plt.xlabel('Date')
plt.ylabel('Probability')
plt.legend()
plt.show()

# Additional Diagnostics on Training Data for Naive Bayes
test_preds_nb = naive_bayes_model.predict(test[predictors])

# Target and Plot
test["NaiveBayes_Target"] = test_preds_nb
combined_nb = pd.concat([test["Target"], test["NaiveBayes_Target"]], axis=1)
combined_nb.columns = ["True", "Predicted"]
combined_nb.plot()
plt.title('Naive Bayes: True vs Predicted')
plt.xlabel('Date')
plt.ylabel('Target')
plt.show()
# Out:
# Precision Score (Naive Bayes): 0.47
# Confusion Matrix (Naive Bayes):
#  [[ 0 53]
#  [ 0 47]]

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import precision_score
import matplotlib.pyplot as plt

# Create GradientBoostingClassifier model
gb_model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=1)

# Train the model
gb_model.fit(train[predictors], train["Target"])

# Predictions on test data
preds_gb = gb_model.predict(test[predictors])

# Calculate precision score
precision_gb = precision_score(test["Target"], preds_gb)
print(f"Precision Score (Gradient Boosting): {precision_gb}")

# Plot true vs predicted values
test["GradientBoosting_Target"] = preds_gb
combined_gb = pd.concat([test["Target"], test["GradientBoosting_Target"]], axis=1)
combined_gb.columns = ["True", "Predicted"]
combined_gb.plot()
plt.title('Gradient Boosting: True vs Predicted')
plt.xlabel('Date')
plt.ylabel('Target')
plt.show()
# Out:
# Precision Score (Gradient Boosting): 0.45263157894736844

# %%
import xgboost as xgb
from sklearn.metrics import precision_score

# Assuming you have already defined train and test datasets, and predictors

# Create XGBoost model
xgb_model = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=1)

# Fit the model
xgb_model.fit(train[predictors], train["Target"])

# Predictions on test data
preds_xgb = xgb_model.predict(test[predictors])

# Calculate precision score
precision_xgb = precision_score(test["Target"], preds_xgb)
print(f"Precision Score (XGBoost): {precision_xgb}")

# Plot the results
combined_xgb = pd.concat([test["Target"], pd.Series(preds_xgb, index=test.index, name="Predictions")], axis=1)
combined_xgb.plot()
# Out:
# Precision Score (XGBoost): 0.4536082474226804
# <Axes: xlabel='Date'>
